# %% [markdown]
# # Gun Violence In U.S.A From 1982 - 2023

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Task - 1 Load the dataset into the pandas DataFrame and examine the first for rows

# %%
shooting_dataset = pd.read_csv(r"C:\Users\lenovo\OneDrive\Desktop\Python\Projects\shooting-1982-2023.csv")

# %%
sd = pd.DataFrame(shooting_dataset) ## Short name of shooting_dataset

# %%
sd ### We have loaded the data and changed into DataFrame
# Out:
#                                       case                   location  \
# 0      Nashville religious school shooting              Nashville, TN
# 1       Michigan State University shooting     East Lansing, Michigan
# 2             Half Moon Bay spree shooting  Half Moon Bay, California
# 3            LA dance studio mass shooting  Monterey Park, California
# 4                Virginia Walmart shooting       Chesapeake, Virginia
# ..                                     ...                        ...
# 136        Shopping centers spree killings          Palm Bay, Florida
# 137  United States Postal Service shooting           Edmond, Oklahoma
# 138         San Ysidro McDonald's massacre     San Ysidro, California
# 139              Dallas nightclub shooting              Dallas, Texas
# 140                  Welding shop shooting             Miami, Florida
#
#            date                                            summary  \
# ...

# %%
sd.head() ## Head will help us to view the first five rows
# Out:
#                                   case                   location      date  \
# 0  Nashville religious school shooting              Nashville, TN   3-27-23
# 1   Michigan State University shooting     East Lansing, Michigan   2-13-23
# 2         Half Moon Bay spree shooting  Half Moon Bay, California   1-23-23
# 3        LA dance studio mass shooting  Monterey Park, California   1-21-23
# 4            Virginia Walmart shooting       Chesapeake, Virginia  11-22-22
#
#                                              summary  fatalities injured  \
# 0  Audrey Hale, 28, who was a former student at t...           6       1
# 1  Anthony D. McRae, 43, opened fire at Berkey Ha...           3       5
# 2  Chunli Zhao, 67, suspected of carrying out the...           7       1
# 3  Huu Can Tran, 72, fled the scene in a white va...          11      10
# 4  Andre Bing, 31, who worked as a supervisor at ...           6       6
#
# ...

# %%
sd.columns ## sd.columns is used to retrieve the column names of a DataFrame
# Out:
# Index(['case', 'location', 'date', 'summary', 'fatalities', 'injured',
#        'total_victims', 'location.1', 'age_of_shooter',
#        'prior_signs_mental_health_issues', 'mental_health_details',
#        'weapons_obtained_legally', 'where_obtained', 'weapon_type',
#        'weapon_details', 'race', 'gender', 'latitude', 'longitude', 'type',
#        'year'],
#       dtype='object')

# %% [markdown]
# # Task 2: Check the dimension of the dataset (No of rows and columns)

# %%
sd.shape ## This will give us count to total rows and columns
# Out:
# (141, 21)

# %% [markdown]
# # Task 3: Identify and handle missing value in dataset

# %%
sd.isnull() ## We are checking null values in our dataset
# Out:
#       case  location   date  summary  fatalities  injured  total_victims  \
# 0    False     False  False    False       False    False          False
# 1    False     False  False    False       False    False          False
# 2    False     False  False    False       False    False          False
# 3    False     False  False    False       False    False          False
# 4    False     False  False    False       False    False          False
# ..     ...       ...    ...      ...         ...      ...            ...
# 136  False     False  False    False       False    False          False
# 137  False     False  False    False       False    False          False
# 138  False     False  False    False       False    False          False
# 139  False     False  False    False       False    False          False
# 140  False     False  False    False       False    False          False
#
#      location.1  age_of_shooter  prior_signs_mental_health_issues  ...  \
# ...

# %%
sd.dropna(inplace=True) ## remove the NaN and blanks values

# %%
sd.shape ## Now the has decreased by 1 before it was 141 rows
# Out:
# (140, 21)

# %%
sd.duplicated().sum() ### To check the counts of duplicate
# Out:
# 0

# %% [markdown]
# # Task 3: Analyze the distribution of gun violence incidents over the years using a line plot

# %%
sd_over_years = sd.groupby("year").sum() ## To make the group by year and then calculate the sum of each group
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_10916\3534155740.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sd_over_years = sd.groupby("year").sum()

# %%
sd_over_years
# Out:
#       fatalities
# year
# 1982           8
# 1984          28
# 1986          15
# 1987           6
# 1988           7
# 1989          15
# 1990          10
# 1991          35
# 1992           9
# 1993          23
# 1994           5
# 1995           6
# 1996           6
# 1997           9
# 1998          14
# 1999          42
# 2000           7
# 2001           5
# 2003           7
# 2004           5
# 2005          17
# 2006          21
# 2007          53
# 2008          17
# 2009          39
# 2010           9
# 2011          19
# 2012          71
# 2013          35
# 2014          18
# 2015          46
# 2016          71
# 2017         117
# 2018          80
# 2019          73
# 2020           9
# 2021          43
# 2022          69
# 2023          27

# %%
plt.figure(figsize=(15, 6), dpi=70, facecolor="#264653") ## Figure size
plt.xlabel("Year") ## Give uus x axis
plt.xticks(sd_over_years.index, rotation= 90) # Give us years in x axis
plt.ylabel("fatalities") ## Give us y axis
plt.title("US gun violence fatalities between 1982 - 2023") ## As we can see the increase in between 2015 to 2019
plt.plot(sd_over_years.index, sd_over_years["fatalities"]) ## For plot chart
plt.scatter(sd_over_years.index, sd_over_years["fatalities"]) ## For scattered chart in line chart

plt.show()

# %% [markdown]
# # Task 5: Calculate the total number of facilities and caused by mass shooting

# %%
grouped_data = sd.groupby("type").sum()
mass_fatalities = grouped_data.loc["Mass", "fatalities"]
print(f"Total fatalities between 1982 to 2023 caused by mass shooting is: {mass_fatalities}")
# Out:
# Total fatalities between 1982 to 2023 caused by mass shooting is: 975
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_10916\121404512.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_data = sd.groupby("type").sum()

# %% [markdown]
# # Task 6: Visualize the top 10 states with the highest number of incident using a bar chart

# %%
sd ## We are not able to find state column in our dataset but we need highest no of incident by state
# Out:
#                                       case                   location  \
# 0      Nashville religious school shooting              Nashville, TN
# 1       Michigan State University shooting     East Lansing, Michigan
# 2             Half Moon Bay spree shooting  Half Moon Bay, California
# 3            LA dance studio mass shooting  Monterey Park, California
# 4                Virginia Walmart shooting       Chesapeake, Virginia
# ..                                     ...                        ...
# 136        Shopping centers spree killings          Palm Bay, Florida
# 137  United States Postal Service shooting           Edmond, Oklahoma
# 138         San Ysidro McDonald's massacre     San Ysidro, California
# 139              Dallas nightclub shooting              Dallas, Texas
# 140                  Welding shop shooting             Miami, Florida
#
#            date                                            summary  \
# ...

# %%
sd["location"] ##we can find state but after ,
# Out:
# 0                  Nashville, TN
# 1         East Lansing, Michigan
# 2      Half Moon Bay, California
# 3      Monterey Park, California
# 4           Chesapeake, Virginia
#                  ...
# 136            Palm Bay, Florida
# 137             Edmond, Oklahoma
# 138       San Ysidro, California
# 139                Dallas, Texas
# 140               Miami, Florida
# Name: location, Length: 140, dtype: object

# %%
state = sd["location"].str.split(",").str[-1].str.strip() ## We are splittinga and removing all the whitespaces

# %%
sd.insert(2, "state", state) ## We are adding using inser

# %%
sd ## Now we can find our state coluumn
# Out:
#                                       case                   location  \
# 0      Nashville religious school shooting              Nashville, TN
# 1       Michigan State University shooting     East Lansing, Michigan
# 2             Half Moon Bay spree shooting  Half Moon Bay, California
# 3            LA dance studio mass shooting  Monterey Park, California
# 4                Virginia Walmart shooting       Chesapeake, Virginia
# ..                                     ...                        ...
# 136        Shopping centers spree killings          Palm Bay, Florida
# 137  United States Postal Service shooting           Edmond, Oklahoma
# 138         San Ysidro McDonald's massacre     San Ysidro, California
# 139              Dallas nightclub shooting              Dallas, Texas
# 140                  Welding shop shooting             Miami, Florida
#
#           state        date  \
# 0            TN     3-27-23
# 1      Michigan     2-13-23
# 2    California     1-23-23
# ...

# %%
incident = sd["state"].value_counts().head(10) ## Counting the values and storing it in variable

# %%
plt.figure(figsize=(8, 5))
plt.title("Top 10 states with highest number of gun violence from 1982-2023")
plt.xticks(fontsize= 9, rotation=45)
plt.bar(incident.index, incident)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# # Task 7: Determine the most common locations where mass shooting occurs

# %%
location_counts = sd["location"].value_counts()
location_with_highest_incident = location_counts.idxmax()
highest_incident_count = location_counts.max()

print(f"Location with the highest incident count is {location_with_highest_incident} and {highest_incident_count} incidents.")
# Out:
# Location with the highest incident count is Colorado Springs, Colorado and 3 incidents.

# %% [markdown]
# # Task 8: Calculate the average number of fatalities and injuries per incident

# %%
sd["injured"] = pd.to_numeric(sd["injured"], errors="coerce") ## to chane in numeric data type

# %%
avg_facilities = sd["fatalities"].mean()
avg_injuries = sd["injured"].mean()
print(f"The average fatalities due to gun violence between 1982-2023 is {avg_facilities}")
print(f"The average injuries due to gun violence between 1982-2023 is {avg_injuries}")
# Out:
# The average fatalities due to gun violence between 1982-2023 is 7.828571428571428
# The average injuries due to gun violence between 1982-2023 is 11.352517985611511

# %% [markdown]
# # Task 9: Explore the relationship between the number of fatalities and the number of injured people using a scatter plot

# %%
fatalities = sd["fatalities"]
injuries = sd["injured"]
plt.scatter(fatalities, injuries)
plt.show()

# %% [markdown]
# # Task 10: Analyze the trend of incidents based on the shooter's gender using a pie chart

# %%
sd.columns
# Out:
# Index(['case', 'location', 'state', 'date', 'summary', 'fatalities', 'injured',
#        'total_victims', 'location.1', 'age_of_shooter',
#        'prior_signs_mental_health_issues', 'mental_health_details',
#        'weapons_obtained_legally', 'where_obtained', 'weapon_type',
#        'weapon_details', 'race', 'gender', 'latitude', 'longitude', 'type',
#        'year'],
#       dtype='object')

# %%
fatalities = sd.groupby("gender").sum()["fatalities"]
labels = ["F", "F (identified as transgender)", "Female", "male", "Male & Female"]
plt.pie(fatalities)
plt.title
plt.axis("equal")
plt.legend(labels, loc="upper left")
plt.savefig("Gun Violence in U.S.A trend based on shooter's gender" format="PNG")
plt.show
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_10916\2464235438.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   fatalities = sd.groupby("gender").sum()["fatalities"]
# <function matplotlib.pyplot.show(close=None, block=None)>
